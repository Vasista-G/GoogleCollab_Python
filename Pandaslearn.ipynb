# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasista-G/GoogleCollab_Python/blob/main/Pandaslearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Owen Harris", "Henry", "Elizabeth", "Mickey"],
    "Age": [22, 35, 58, 22],
    "Gender": ["male", "male", "female", "male"]
})

df
# Out:
#           Name  Age  Gender
# 0  Owen Harris   22    male
# 1        Henry   35    male
# 2    Elizabeth   58  female
# 3       Mickey   22    male

# %%
df = pd.read_csv("coffee.csv", )

df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.loc[df["Day"] == "Monday", ["Day", "Units Sold"]]


#df.loc[(df["Units Sold"] > 25) & (df["Day"].isin(["Saturday", "Sunday"]))]

df[df["Day"].str.contains("sat", case = False)]
# Out:
#          Day Coffee Type  Units Sold
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35

# %%
df["Price"] = 5

def NewPrice(row):
    if row["Coffee Type"] == "Espresso":
        return 5
    else:
        return 4

df["New_price"] = df.apply(NewPrice, axis = 1)

df
# Out:
#           Day Coffee Type  Units Sold  Price  New_price
# 0      Monday    Espresso          25      5          5
# 1      Monday       Latte          15      5          4
# 2     Tuesday    Espresso          30      5          5
# 3     Tuesday       Latte          20      5          4
# 4   Wednesday    Espresso          35      5          5
# 5   Wednesday       Latte          25      5          4
# 6    Thursday    Espresso          40      5          5
# 7    Thursday       Latte          30      5          4
# 8      Friday    Espresso          45      5          5
# 9      Friday       Latte          35      5          4
# 10   Saturday    Espresso          45      5          5
# 11   Saturday       Latte          35      5          4
# 12     Sunday    Espresso          45      5          5
# 13     Sunday       Latte          35      5          4
